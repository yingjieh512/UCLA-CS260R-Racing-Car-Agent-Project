# %%
import os

try:
    from google.colab import drive
    drive.mount('/content/gdrive')

    DRIVE_PATH = '/content/gdrive/My Drive/my_mini_project'  # No need for backslash
    if not os.path.exists(DRIVE_PATH):
        # !mkdir -p "$DRIVE_PATH"  # Ensure the folder exists

    # Create a symlink to avoid issues with spaces in 'My Drive'
    SYM_PATH = '/content/my_mini_project'
    if not os.path.exists(SYM_PATH):
        # !ln -s "$DRIVE_PATH" "$SYM_PATH"

    running_in_colab = True

    # We already mounted in our google drive.
    # Enter the foler where you put files in:
    # %cd '/content/my_mini_project/mini_project'

except ModuleNotFoundError:
    running_in_colab = False
    print("I guess you are running locally. If you get this message in Colab, something is wrong.")

print("\nCurrent working directory:")
# !pwd

print("\nWhat files are there:")
# !ls
# Out:
# Mounted at /content/gdrive
# /content/gdrive/My Drive/my_mini_project/mini_project
#
# Current working directory:
# /content/gdrive/My Drive/my_mini_project/mini_project
#
# What files are there:
# agents	     environment.yml  logs	      README.md
# assets	     env.py	      __pycache__     requirements.txt
# checkpoints  eval_local.py    racing_maps.py  train.py

# %%
# !pip install stable-baselines3
# !pip install torch

# Install MetaDrive, a lightweight driving simulator
# !pip install git+https://github.com/metadriverse/metadrive

# Test whether MetaDrive is properly installed. No error means the test is passed.
# !python -m metadrive.examples.profile_metadrive --num-steps 100

# !pip install pandas scipy seaborn tabulate pyyaml
# !pip install torch mediapy numpy scipy tqdm pandas pyyaml "gymnasium<1.0.0"
# !pip install tensorboard
# !pip install numpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 10.8 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/metadriverse/metadrive to /tmp/pip-req-build-6rtnaw8n
#   Running command git clone --filter=blob:none --quiet https://github.com/metadriverse/metadrive /tmp/pip-req-build-6rtnaw8n
#   Resolved https://github.com/metadriverse/metadrive to commit 85e5dadc6c7436d324348f6e3d8f8e680c06b4db
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 44.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.5 MB/s eta 0:00:00
# ...

# %%
# !python train.py --total-timesteps 3000000
# Out:
# 2026-03-19 20:05:15.730647: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 20:05:15.733384: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-03-19 20:05:15.740474: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773950715.753934   17473 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773950715.757656   17473 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python eval_local.py --agent-dirs agents/agent_205927975
# Out:
# Evaluating agents/agent_205927975 vs aggressive on 'circuit':
# [INFO] Environment: MultiAgentRacingEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 3000
# [WARNING] When reaching max steps, both 'terminate' and 'truncate will be True.Generally, only the `truncate` should be `True`. (base_env.py:395)
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: glxGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# Actually spawned: ['agent0', 'agent1']
#   Ep 0: reward=2187.89, route=99.72%, speed=67.7 km/h, arrive=True
# Actually spawned: ['agent0', 'agent1']
#   Ep 1: reward=2248.71, route=99.75%, speed=69.0 km/h, arrive=True
# Actually spawned: ['agent0', 'agent1']
#   Ep 2: reward=1208.05, route=54.24%, speed=68.1 km/h, arrive=False
# Actually spawned: ['agent0', 'agent1']
# ...

# %%
# !python eval_local.py --agent-dirs agents/agent_205927975 agents/example_agent --mode versus
# Out:
# Racing 2 agents on 'circuit':
#   agent0 <- agents/agent_205927975
#   agent1 <- agents/example_agent
# [INFO] Environment: MultiAgentRacingEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 3000
# [WARNING] When reaching max steps, both 'terminate' and 'truncate will be True.Generally, only the `truncate` should be `True`. (base_env.py:395)
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: glxGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# Actually spawned: ['agent0', 'agent1']
#   Ep 0: winner=agent0 | agent0: route=99.73%, speed=73.7 km/h (arrived@step 1050) | agent1: route=99.68%, speed=69.9 km/h (arrived@step 1111)
# Actually spawned: ['agent0', 'agent1']
#   Ep 1: winner=agent1 | agent0: route=99.73%, speed=68.4 km/h (arrived@step 1133) | agent1: route=99.74%, speed=71.6 km/h (arrived@step 1080)
# ...

# %%
# !python eval_local.py --agent-dirs agents/agent_205927975 agents/baseline_agent --mode versus
# Out:
# Racing 2 agents on 'circuit':
#   agent0 <- agents/agent_205927975
#   agent1 <- agents/baseline_agent
# [INFO] Environment: MultiAgentRacingEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): 3000
# [WARNING] When reaching max steps, both 'terminate' and 'truncate will be True.Generally, only the `truncate` should be `True`. (base_env.py:395)
# [INFO] Assets version: 0.4.3
# [INFO] Known Pipes: glxGraphicsPipe
# [INFO] Start Scenario Index: 0, Num Scenarios : 1
# Actually spawned: ['agent0', 'agent1']
#   Ep 0: winner=agent0 | agent0: route=99.72%, speed=71.8 km/h (arrived@step 1083) | agent1: route=12.79%, speed=50.7 km/h
# Actually spawned: ['agent0', 'agent1']
#   Ep 1: winner=agent0 | agent0: route=99.72%, speed=71.9 km/h (arrived@step 1079) | agent1: route=91.70%, speed=47.6 km/h
# Actually spawned: ['agent0', 'agent1']
# ...
